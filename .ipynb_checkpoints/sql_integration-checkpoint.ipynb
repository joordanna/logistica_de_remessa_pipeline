# %%
import pyodbc

dados_conexao = (
    "Driver={SQL Server};"
    "Server=DESKTOP-0UN1LB3\\SQLEXPRESS;"
    "Database=shipment_logistics;"
)

conexao = pyodbc.connect(dados_conexao)
cursor = conexao.cursor()
print('Conexão bem sucedida')
# Out:
# Conexão bem sucedida

# %%
#pegando os dataframes tratados. Salvo no notebook de tratamento
import pandas as pd

df_refinado = pd.read_csv("df_refinado.csv")

# %%
df_refinado.columns.tolist()
# Out:
# ['Origin',
#  'Destination',
#  'Pouch No',
#  'Date',
#  'Consignment No',
#  'Receive Date',
#  'Expiry Date',
#  'Total Pieces',
#  'Actual Wt',
#  'Volumetric Wt',
#  'Chargeable Wt',
#  'Tariff',
#  'VAS Charges',
#  'Total Amount',
#  'Mode',
#  'Mode of Payment',
#  'Nature of Consignment',
#  'Risk Surcharge',
#  'Sender City',
#  'Sender State',
#  'Sender Pincode',
#  'Recipient City',
#  'Receiver State',
#  'Receiver Pincode']

# %%
colunas = df_refinado.columns.tolist()

column_names = ", ".join([f"[{col}]" for col in colunas])
placeholders = ", ".join(["?"] * len(colunas))

insert_query = f"""
INSERT INTO ShipmentLogistics ({column_names})
VALUES ({placeholders})
"""

values = df_refinado.itertuples(index=False, name=None)

cursor.executemany(insert_query, values)
conexao.commit()

print("Dados inseridos com sucesso!")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[10], line 13
#       6 insert_query = f"""
#       7 INSERT INTO ShipmentLogistics ({column_names})
#       8 VALUES ({placeholders})
#       9 """
#      11 values = df_refinado.itertuples(index=False, name=None)
# ---> 13 cursor.executemany(insert_query, values)
#      14 conexao.commit()
#      16 print("Dados inseridos com sucesso!")
#
# ProgrammingError: ('42S22', "[42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Pouch No' inválido. (207) (SQLExecDirectW); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Consignment No' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Receive Date' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Expiry Date' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Total Pieces' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Actual Wt' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Volumetric Wt' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Chargeable Wt' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'VAS Charges' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Total Amount' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Mode of Payment' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Nature of Consignment' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Risk Surcharge' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Sender City' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Sender State' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Sender Pincode' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Recipient City' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Receiver State' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Nome de coluna 'Receiver Pincode' inválido. (207); [42S22] [Microsoft][ODBC SQL Server Driver][SQL Server]Não foi possível preparar uma ou mais instruções. (8180)")
